# %% [markdown]
# <a href="https://colab.research.google.com/github/2006asthagautam-dot/asthag/blob/main/music_recommendor.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import kagglehub
import pandas as pd
import os
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics.pairwise import cosine_similarity


path = kagglehub.dataset_download("maharshipandya/-spotify-tracks-dataset")
df = pd.read_csv(os.path.join(path, 'dataset.csv')).drop_duplicates(subset=['track_name', 'artists']).dropna()


features = ['danceability', 'energy', 'loudness', 'speechiness', 'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo']
scaler = MinMaxScaler()
df_scaled = scaler.fit_transform(df[features])


subset_limit = 20000
df_subset = df.head(subset_limit).reset_index(drop=True)
scaled_subset = df_scaled[:subset_limit]

# Calculate Similarity Matrix
similarity_matrix = cosine_similarity(scaled_subset)
print("✅ Data Loaded and Model Trained!")
# Out:
# ...
# 100%|██████████| 8.17M/8.17M [00:00<00:00, 112MB/s]
# Extracting files...
# ✅ Data Loaded and Model Trained!

# %%
def recommend_me_music(song_name, num_recommendations=5):
    match = df_subset[df_subset['track_name'].str.contains(song_name, case=False, na=False)]
    if match.empty:
        return f"Song '{song_name}' not found."

    idx = match.index[0]
    sim_scores = sorted(list(enumerate(similarity_matrix[idx])), key=lambda x: x[1], reverse=True)
    recommended_indices = [i[0] for i in sim_scores[1:num_recommendations+1]]

    print(f"✅ Recommendations for: {df_subset.iloc[idx]['track_name']}")
    return df_subset.iloc[recommended_indices][['track_name', 'artists', 'track_genre']]

# %%
recommend_me_music("Pink")
# Out:
# ✅ Recommendations for: Pink Sky Moon
#                        track_name            artists track_genre
# 10948                    沒結果的一些感情   Christopher Wong    cantopop
# 526                 Missing Peace          JJ Heller    acoustic
# 9456   Say a Little Prayer - Live    Lianne La Havas     british
# 10294                    她來聽我的演唱會       Jacky Cheung    cantopop
# 10648                 20GB - Live  my little airport    cantopop
